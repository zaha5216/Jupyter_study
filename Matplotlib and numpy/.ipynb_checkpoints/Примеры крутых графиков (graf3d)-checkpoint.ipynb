# %%
import  matplotlib  as  mpl

# %%
import numpy as np

# %%
import plotly

# %%
import matplotlib.pyplot as plt

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
t = np.linspace( -13, 13, 1001, dtype= np.float64)

# %%
z = t / 5

# %%
r = z**2 + 1

# %%
x = r * np.cos(t)

# %%
y = r * np.sin(t)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.gca( projection='3d')
ax.plot(x, y, z)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot( x, y, z, label='line 1')
ax.plot( x, z, y, label='line 2')
ax.legend()

# %%
fig = plt.figure()
ax1 = fig.add_subplot( 1, 2, 1, projection='3d' )
ax2 = fig.add_subplot( 1, 2, 2, projection='3d' )
ax1.plot(x, y, z)
ax2.plot(x, z, y)

# %%
# r = (x^2+y^2)/x^2+y^2)
# z = e^-6^2*cosr

# %%
x = np.linspace( -10, 10, 2001 )

# %%
y = np.linspace( -10, 10, 2001 )

# %%
X1, Y1 = np.meshgrid(x,y)

# %%
X1
# Out:
# array([[-10.  ,  -9.99,  -9.98, ...,   9.98,   9.99,  10.  ],
#        [-10.  ,  -9.99,  -9.98, ...,   9.98,   9.99,  10.  ],
#        [-10.  ,  -9.99,  -9.98, ...,   9.98,   9.99,  10.  ],
#        ...,
#        [-10.  ,  -9.99,  -9.98, ...,   9.98,   9.99,  10.  ],
#        [-10.  ,  -9.99,  -9.98, ...,   9.98,   9.99,  10.  ],
#        [-10.  ,  -9.99,  -9.98, ...,   9.98,   9.99,  10.  ]])

# %%
y
# Out:
# array([-10.  ,  -9.99,  -9.98, ...,   9.98,   9.99,  10.  ])

# %%
Y1
# Out:
# array([[-10.  , -10.  , -10.  , ..., -10.  , -10.  , -10.  ],
#        [ -9.99,  -9.99,  -9.99, ...,  -9.99,  -9.99,  -9.99],
#        [ -9.98,  -9.98,  -9.98, ...,  -9.98,  -9.98,  -9.98],
#        ...,
#        [  9.98,   9.98,   9.98, ...,   9.98,   9.98,   9.98],
#        [  9.99,   9.99,   9.99, ...,   9.99,   9.99,   9.99],
#        [ 10.  ,  10.  ,  10.  , ...,  10.  ,  10.  ,  10.  ]])

# %%
R2 = X1**2 + Y1**2

# %%
R = np.sqrt(R2)

# %%
z = np.exp(-R2) * np.cos(R)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_wireframe( X1, Y1, z)

# %%
z = np.exp(-R2/16) * np.cos(R)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_wireframe( X1, Y1, z, rcount=15, ccount=15)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface( X1, Y1, z,)

# %%
A = [ 10, 15, 3, 0 ]

# %%
B = [ 15, 14, 3, 25 ]

# %%
fig = plt.figure()
old = fig.add_subplot( 1, 2, 1 )
new = fig.add_subplot( 1, 2, 2 )
names = [ 'Вася', 'Петя', 'Коля', 'Саша']
old.pie( A, labels=names )
new.pie( B,labels=names)
# Out:
# ([<matplotlib.patches.Wedge at 0x11fd0f400>,
#   <matplotlib.patches.Wedge at 0x11fd0f898>,
#   <matplotlib.patches.Wedge at 0x11fd0fcf8>,
#   <matplotlib.patches.Wedge at 0x11fce1240>],
#  [Text(0.7450097048603818, 0.8092963237676586, 'Вася'),
#   Text(-0.8295173176268907, 0.7224271726320158, 'Петя'),
#   Text(-1.0733760036036752, -0.24054927746264995, 'Коля'),
#   Text(0.21088175984222315, -1.0795966299344617, 'Саша')])

# %%
idx = np.linspace( 0, 10, 4, dtype=np.float32)

# %%
wid = 0.5

# %%
plt.bar( idx, A, wid, color='b',label='2010')
plt.bar( idx+wid, B, wid, color='r',label='2015')
plt.xticks( idx+wid/2, names )
plt.legend()

# %%
plt.bar( idx, A, wid, color='b',label='2010')
plt.bar( idx, B, wid, color='r',label='2015', bottom=A )
plt.xticks( idx+wid/2, names )
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>
