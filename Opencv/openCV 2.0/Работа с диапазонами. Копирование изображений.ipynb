# %%
# %matplotlib inline
from skimage.io import imread, imshow, imsave
img = imread('/Users/zaha/Documents/tigr-color .jpeg')

# %%
nose = img[350:400, 630:720]

# %%
imshow(nose)

# %%
img[350:400, 630:720] = [249, 249, 249]

# %%
imshow(img)

# %%
img_yellow = imread('/Users/zaha/Примеры решений/Opencv/openCV 2.0/tiger-yellow-nose.png')

# %%
imshow(img_yellow[350:400, 630:720])

# %%
img_assigned = img_yellow

# %%
img_copy =img_yellow.copy()

# %%
img_yellow[350:400, 630:720] = [255, 0, 255]

# %%
imshow(img_yellow)

# %%
imshow(img_assigned)

# %%
imshow(img_copy)
