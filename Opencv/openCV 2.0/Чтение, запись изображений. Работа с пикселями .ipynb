# %%
 # %matplotlib inline

# %%
from skimage.io import imread, imshow, imsave

# %%
img = imread('/Users/zaha/Documents/tigr-color .jpeg')

# %%
imshow(img)

# %%
img.shape # ( Строки,Столбы,кол-во каналовRGB)
# Out:
# (750, 1200, 3)

# %%
img.shape[1]
# Out:
# 1200

# %%
img[450,600] #Показывает цвет пикселя
# Out:
# array([166, 161, 155], dtype=uint8)

# %%
img[450,600, 2]
# Out:
# 155

# %%
img[380, 680] = [255, 255, 0]

# %%
imsave('tiger-yellow-nose.png', img)
