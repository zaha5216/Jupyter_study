# %%
# %matplotlib inline
from skimage.io import imread, imshow, imsave
img = imread('/Users/zaha/Documents/tigr-color .jpeg')

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
from skimage import img_as_float

# %%
img_f = img_as_float(img) # переводит в флоат в число

# %%
img.min(), img.max()
# Out:
# (0, 255)

# %%
img_f.min(), img_f.max()
# Out:
# (0.0, 1.0)

# %%
imshow(img_f/1.5)

# %%
imshow(img_f/2)

# %%
imshow(img_f/4)

# %%
imshow(img_f/4+0.25)

# %%
from numpy import clip

# %%
imshow(clip(img_f * 1.5, 0, 1))

# %%
imshow(clip(img_f * 2, 0, 1))

# %%
imshow(clip(img_f * 2 - 0.5, 0, 1))
